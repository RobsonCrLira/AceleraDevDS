# %% [markdown]
# Importação das bibliotecas

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
drive.mount('/content/drive')


# %matplotlib inline
# %precision %.2f
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/My Drive/Codenation/Projeto/estaticos_portfolio1.csv')
df2 = pd.read_csv('/content/drive/My Drive/Codenation/Projeto/estaticos_portfolio2.csv')
df3 = pd.read_csv('/content/drive/My Drive/Codenation/Projeto/estaticos_portfolio3.csv')
df = pd.read_csv('/content/drive/My Drive/Codenation/Projeto/estaticos_market.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  ... qt_filiais
# 0           0  ...          0
# 1           1  ...          0
# 2           2  ...          0
# 3           3  ...          0
# 4           4  ...          0
#
# [5 rows x 182 columns]

# %%
def printa(dfs):
    aux = pd.DataFrame({'colunas': dfs.columns,
                    'tipos': dfs.dtypes,
                    'percentual_faltante': dfs.isna().sum() / dfs.shape[0]})
    return aux.values

# %%
printa(df)
# Out:
# array([['Unnamed: 0', dtype('int64'), 0.0],
#        ['id', dtype('O'), 0.0],
#        ['fl_matriz', dtype('bool'), 0.0],
#        ['de_natureza_juridica', dtype('O'), 0.0],
#        ['sg_uf', dtype('O'), 0.0],
#        ['natureza_juridica_macro', dtype('O'), 0.0],
#        ['de_ramo', dtype('O'), 0.0],
#        ['setor', dtype('O'), 0.004168307022742906],
#        ['idade_empresa_anos', dtype('float64'), 0.0],
#        ['idade_emp_cat', dtype('O'), 0.0],
#        ['fl_me', dtype('bool'), 0.0],
#        ['fl_sa', dtype('bool'), 0.0],
#        ['fl_epp', dtype('bool'), 0.0],
#        ['fl_mei', dtype('bool'), 0.0],
#        ['fl_ltda', dtype('bool'), 0.0],
#        ['dt_situacao', dtype('O'), 1.2978641482333906e-05],
#        ['fl_st_especial', dtype('bool'), 0.0],
#        ['fl_email', dtype('bool'), 0.0],
#        ['fl_telefone', dtype('bool'), 0.0],
#        ['fl_rm', dtype('O'), 0.0],
#        ['nm_divisao', dtype('O'), 0.004168307022742906],
# ...
